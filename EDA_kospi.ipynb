# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("raw_data.xlsx")

# %%
df.head()
# Out:
#     Symbol  Name   결산월   회계년      주기  타인자본비율(%) 자기자본비율(%)  차입금의존도(%)  \
# 0  A000010  조흥은행  12.0  2003  Annual      96.76      3.24      19.72
# 1  A000090  두산상사  12.0  1997  Annual      90.84      9.16      68.03
# 2  A000110  제일은행  12.0  2004  Annual      95.61      4.39      24.51
# 3  A000130  한일은행  12.0  1998  Annual      96.85      3.15      23.28
# 4  A000160  대한중석  12.0  1998  Annual     137.30      완전잠식       0.00
#
#    현금및현금성자산구성비율(%)  유형자산구성비율(%)  ...  현금흐름/영업수익(%) 현금흐름/총부채(%) 현금흐름/총자본(%)  \
# 0             1.52         2.12  ...        -13.48       -1.22      -35.07
# 1             9.03        16.37  ...         -0.91        -1.6      -12.21
# 2             1.19         2.71  ...          7.32        0.51       11.34
# 3             1.89         2.18  ...          1.09        0.13         3.5
# 4             2.54        17.40  ...       -427.84      -57.25     -365.51
#
#   현금흐름/총자산(%) 현금흐름/총차입부채(%)  유보율(%)  유보액/총자산(%) 시가총액(1YRF) 시가총액(2YRF) Target
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1136 entries, 0 to 1135
# Data columns (total 26 columns):
# Symbol             1136 non-null object
# Name               1136 non-null object
# 결산월                1130 non-null float64
# 회계년                1136 non-null int64
# 주기                 1136 non-null object
# 타인자본비율(%)          1136 non-null float64
# 자기자본비율(%)          1136 non-null object
# 차입금의존도(%)          1136 non-null float64
# 현금및현금성자산구성비율(%)    1136 non-null float64
# 유형자산구성비율(%)        1136 non-null float64
# 무형자산구성비율(%)        1136 non-null float64
# 부채비율(%)            1136 non-null object
# 차입금비율(%)           1136 non-null object
# 총자산/총자본(%)         1136 non-null object
# 차입부채조달금리(평균)(%)    1136 non-null object
# 차입부채조달금리(기말)(%)    1136 non-null float64
# 현금흐름/영업수익(%)       1136 non-null float64
# 현금흐름/총부채(%)        1136 non-null object
# 현금흐름/총자본(%)        1136 non-null object
# 현금흐름/총자산(%)        1136 non-null object
# ...

# %%
df['현금흐름/총부채(%)']
# Out:
# 0       -1.22
# 1        -1.6
# 2        0.51
# 3        0.13
# 4      -57.25
#         ...
# 1131   -10.16
# 1132     -4.6
# 1133     6.58
# 1134   -29.45
# 1135     9.65
# Name: 현금흐름/총부채(%), Length: 1136, dtype: object

# %%
df[df['현금흐름/총부채(%)']=="N/A(IFRS)"]
# Out:
#       Symbol    Name   결산월   회계년      주기  타인자본비율(%) 자기자본비율(%)  차입금의존도(%)  \
# 19   A000800    경남기업  12.0  2014  Annual     108.91      완전잠식      76.74
# 113  A005270    대구은행  12.0  2010  Annual      93.25      6.75      20.66
# 114  A005280    부산은행  12.0  2010  Annual      92.70       7.3      18.29
# 359  A121910  대우증권스팩   3.0  2011  Annual       5.41     94.59       4.88
# 360  A122290  동양밸류스팩   6.0  2011  Annual       5.39     94.61       4.61
#
#      현금및현금성자산구성비율(%)  유형자산구성비율(%)  ...  현금흐름/영업수익(%) 현금흐름/총부채(%) 현금흐름/총자본(%)  \
# 19              3.28        23.08  ...        -33.23   N/A(IFRS)   N/A(IFRS)
# 113             1.11         1.00  ...          8.82   N/A(IFRS)   N/A(IFRS)
# 114             4.79         1.00  ...         14.49   N/A(IFRS)   N/A(IFRS)
# 359             0.36         0.00  ...          3.97   N/A(IFRS)   N/A(IFRS)
# 360            10.80         0.00  ...          3.97   N/A(IFRS)   N/A(IFRS)
#
# ...

# %%
# 데이터 셋에서 "완전잠식", "N/A(IFRS)" 등 문자형 값이 존재함
# "자기자본비율(%)"은 -1 로 대체
# "차입부채조달금리(평균)(%)"은 0으로 대체
# 나머지 문자형 값들은 각 그룹별(상장폐지/상장) 평균값으로 대체

# %%
type(df["자기자본비율(%)"][0]) == float
# Out:
# True

# %%
object_col = []

# %%
for c in df.columns:
    if df[c].dtype == "object":
        print(c)
        
        object_col.append(c)
# Out:
# Symbol
# Name
# 주기
# 자기자본비율(%)
# 부채비율(%)
# 차입금비율(%)
# 총자산/총자본(%)
# 차입부채조달금리(평균)(%)
# 현금흐름/총부채(%)
# 현금흐름/총자본(%)
# 현금흐름/총자산(%)
# 현금흐름/총차입부채(%)

# %%
object_col
# Out:
# ['Symbol',
#  'Name',
#  '주기',
#  '자기자본비율(%)',
#  '부채비율(%)',
#  '차입금비율(%)',
#  '총자산/총자본(%)',
#  '차입부채조달금리(평균)(%)',
#  '현금흐름/총부채(%)',
#  '현금흐름/총자본(%)',
#  '현금흐름/총자산(%)',
#  '현금흐름/총차입부채(%)']

# %%
del object_col[0:3]

# %%
object_col
# Out:
# ['자기자본비율(%)',
#  '부채비율(%)',
#  '차입금비율(%)',
#  '총자산/총자본(%)',
#  '차입부채조달금리(평균)(%)',
#  '현금흐름/총부채(%)',
#  '현금흐름/총자본(%)',
#  '현금흐름/총자산(%)',
#  '현금흐름/총차입부채(%)']

# %%
for c in object_col:

    for t in range(len(df[c])):

        # print(type(df[c][t]), df[c][t])

        if type(df[c][t]) == str:

            print(c, df[c][t])
# Out:
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# 자기자본비율(%) 완전잠식
# ...

# %%
df[object_col].describe()
# Out:
#        자기자본비율(%) 부채비율(%) 차입금비율(%) 총자산/총자본(%)  차입부채조달금리(평균)(%) 현금흐름/총부채(%)  \
# count       1136    1136     1136       1136             1136        1136
# unique       975    1023      941       1023              655        1003
# top         완전잠식    완전잠식     완전잠식       완전잠식                0   N/A(IFRS)
# freq          95      90       90         90               37           5
#
#        현금흐름/총자본(%)  현금흐름/총자산(%) 현금흐름/총차입부채(%)
# count         1136         1136          1136
# unique         918          906          1072
# top           완전잠식            0     N/A(IFRS)
# freq            82            7             7

# %%
df.describe()
# Out:
#                결산월          회계년    타인자본비율(%)    차입금의존도(%)  현금및현금성자산구성비율(%)  \
# count  1130.000000  1136.000000  1136.000000  1136.000000      1136.000000
# mean     11.399115  2012.627641    66.135810    33.515317         6.511012
# std       2.128094     7.249699    74.304975    62.468893         7.260541
# min       1.000000  1994.000000     0.000000     0.000000         0.000000
# 25%      12.000000  2009.000000    35.477500     9.030000         1.750000
# 50%      12.000000  2017.000000    56.550000    25.260000         4.310000
# 75%      12.000000  2017.000000    80.090000    42.515000         8.372500
# max      12.000000  2018.000000  1247.190000  1408.830000        61.930000
#
#        유형자산구성비율(%)  무형자산구성비율(%)  차입부채조달금리(기말)(%)   현금흐름/영업수익(%)  \
# count  1136.000000  1136.000000      1136.000000    1136.000000
# mean     30.197236     3.031690        11.314621     486.566699
# std      21.598223     6.479241        61.098734   17907.670158
# ...

# %%
df[df["차입부채조달금리(기말)(%)"]==1612.090000] # 이상값으로 추정되어 추후 제거 또는 평균값으로 대체
# Out:
#       Symbol  Name   결산월   회계년      주기  타인자본비율(%) 자기자본비율(%)  차입금의존도(%)  \
# 542  A226320  잇츠한불  12.0  2017  Annual      16.56     83.44       0.01
#
#      현금및현금성자산구성비율(%)  유형자산구성비율(%)  ...  현금흐름/영업수익(%) 현금흐름/총부채(%) 현금흐름/총자본(%)  \
# 542             9.43         7.94  ...          14.6       31.98        8.18
#
#     현금흐름/총자산(%) 현금흐름/총차입부채(%)   유보율(%)  유보액/총자산(%) 시가총액(1YRF) 시가총액(2YRF)  \
# 542        6.51         204.3  3887.96        75.8     588802     995591
#
#     Target
# 542      0
#
# [1 rows x 26 columns]

# %%
df["자기자본비율(%)"] = df["자기자본비율(%)"].apply(lambda x: -1 if x=="완전잠식" else x)
df["차입부채조달금리(평균)(%)"] = df["차입부채조달금리(평균)(%)"].apply(lambda x: 0 if x=="N/A(IFRS)" else x)
df["현금흐름/총자본(%)"] = df["현금흐름/총자본(%)"].apply(lambda x: np.nan if x=="완전잠식" else x)
df["현금흐름/총부채(%)"] = df["현금흐름/총부채(%)"].apply(lambda x: np.nan if x=="완전잠식" else x)
df["현금흐름/총자산(%)"] = df["현금흐름/총자산(%)"].apply(lambda x: np.nan if x=="완전잠식" else x)
df["현금흐름/총차입부채(%)"] = df["현금흐름/총차입부채(%)"].apply(lambda x: np.nan if x=="완전잠식" else x)
df["부채비율(%)"] = df["부채비율(%)"].apply(lambda x: np.nan if x=="완전잠식" else x)
df["차입금비율(%)"] = df["차입금비율(%)"].apply(lambda x: np.nan if x=="완전잠식" else x)
df["총자산/총자본(%)"] = df["총자산/총자본(%)"].apply(lambda x: np.nan if x=="완전잠식" else x)

# %%
df[object_col].describe()
# Out:
#          자기자본비율(%)       부채비율(%)      차입금비율(%)    총자산/총자본(%)  차입부채조달금리(평균)(%)
# count  1136.000000   1046.000000   1046.000000   1046.000000      1136.000000
# mean     42.192711    422.285985    209.148279    522.285985         7.702923
# std      27.168933   1751.618431   1283.491835   1751.618431        33.163701
# min      -1.000000      4.750000      0.000000    104.750000         0.000000
# 25%      18.915000     53.270000     16.525000    153.270000         2.510000
# 50%      42.960000    115.835000     53.610000    215.835000         3.700000
# 75%      63.455000    276.192500    130.062500    376.192500         7.610000
# max      95.470000  37119.360000  27771.010000  37219.360000      1055.300000

# %%
df[["현금흐름/총자본(%)","현금흐름/총부채(%)","현금흐름/총자산(%)","현금흐름/총차입부채(%)"]]
# Out:
#      현금흐름/총자본(%) 현금흐름/총부채(%) 현금흐름/총자산(%) 현금흐름/총차입부채(%)
# 0         -35.07       -1.22       -1.17         -6.19
# 1         -12.21        -1.6       -1.41         -2.15
# 2          11.34        0.51        0.48          2.23
# 3            3.5        0.13        0.13          0.56
# 4        -365.51      -57.25       -49.5       -108.71
# ...          ...         ...         ...           ...
# 1131       -14.9      -10.16       -6.04        -14.23
# 1132       -3.87        -4.6        -2.1         -7.87
# 1133         2.7        6.58        1.92       1687.32
# 1134       -6.86      -29.45       -5.56       -103.18
# 1135        9.24        9.65        4.72         39.56
#
# [1136 rows x 4 columns]

# %%
df[(df["현금흐름/총부채(%)"] == "N/A(IFRS)") | (df["현금흐름/총자산(%)"] == "N/A(IFRS)") | (df["현금흐름/총차입부채(%)"] == "N/A(IFRS)") | (df["현금흐름/총자본(%)"] == "N/A(IFRS)")]
# Out:
#        Symbol    Name   결산월   회계년      주기  타인자본비율(%)  자기자본비율(%)  차입금의존도(%)  \
# 19    A000800    경남기업  12.0  2014  Annual     108.91      -1.00      76.74
# 113   A005270    대구은행  12.0  2010  Annual      93.25       6.75      20.66
# 114   A005280    부산은행  12.0  2010  Annual      92.70       7.30      18.29
# 359   A121910  대우증권스팩   3.0  2011  Annual       5.41      94.59       4.88
# 360   A122290  동양밸류스팩   6.0  2011  Annual       5.39      94.61       4.61
# 918   A000650    천일고속  12.0  2017  Annual      30.52      69.48       0.00
# 1117  A009140    경인전자  12.0  2017  Annual       6.34      93.66       0.00
#
#       현금및현금성자산구성비율(%)  유형자산구성비율(%)  ...  현금흐름/영업수익(%)  현금흐름/총부채(%)  \
# 19               3.28        23.08  ...        -33.23    N/A(IFRS)
# 113              1.11         1.00  ...          8.82    N/A(IFRS)
# 114              4.79         1.00  ...         14.49    N/A(IFRS)
# 359              0.36         0.00  ...          3.97    N/A(IFRS)
# ...

# %%
df[(df["현금흐름/총부채(%)"] == "N/A(IFRS)") | (df["현금흐름/총자산(%)"] == "N/A(IFRS)") | (df["현금흐름/총차입부채(%)"] == "N/A(IFRS)") | (df["현금흐름/총자본(%)"] == "N/A(IFRS)")].index
# Out:
# Int64Index([19, 113, 114, 359, 360, 918, 1117], dtype='int64')

# %%
df.drop([113,114], inplace = True)
df.drop([359,360], inplace = True)

# %%
df[(df["현금흐름/총부채(%)"] == "N/A(IFRS)") | (df["현금흐름/총자산(%)"] == "N/A(IFRS)") | (df["현금흐름/총차입부채(%)"] == "N/A(IFRS)") | (df["현금흐름/총자본(%)"] == "N/A(IFRS)")]
# Out:
#        Symbol  Name   결산월   회계년      주기  타인자본비율(%)  자기자본비율(%)  차입금의존도(%)  \
# 19    A000800  경남기업  12.0  2014  Annual     108.91      -1.00      76.74
# 918   A000650  천일고속  12.0  2017  Annual      30.52      69.48       0.00
# 1117  A009140  경인전자  12.0  2017  Annual       6.34      93.66       0.00
#
#       현금및현금성자산구성비율(%)  유형자산구성비율(%)  ...  현금흐름/영업수익(%)  현금흐름/총부채(%)  \
# 19               3.28        23.08  ...        -33.23    N/A(IFRS)
# 918              3.74        23.20  ...         53.79       172.83
# 1117            40.46         7.34  ...        -11.37       -59.97
#
#       현금흐름/총자본(%)  현금흐름/총자산(%)  현금흐름/총차입부채(%)  유보율(%)  유보액/총자산(%) 시가총액(1YRF)  \
# 19      N/A(IFRS)    N/A(IFRS)      N/A(IFRS)   58.83        1.94     125916
# 918         69.12        49.37      N/A(IFRS)  560.67       59.06     113480
# 1117        -4.32        -4.03      N/A(IFRS)  662.96       87.00      34165
#
#      시가총액(2YRF) Target
# 19       631951      1
# 918      135347      0
# ...

# %%
#df_IFRS = df[(df["현금흐름/총부채(%)"] == "N/A(IFRS)") | (df["현금흐름/총자산(%)"] == "N/A(IFRS)") | (df["현금흐름/총차입부채(%)"] == "N/A(IFRS)") | (df["현금흐름/총자본(%)"] == "N/A(IFRS)")]

# %%
df["현금흐름/총자본(%)"] = df["현금흐름/총자본(%)"].apply(lambda x: np.nan if x=="N/A(IFRS)" else x)
df["현금흐름/총부채(%)"] = df["현금흐름/총부채(%)"].apply(lambda x: np.nan if x=="N/A(IFRS)" else x)
df["현금흐름/총자산(%)"] = df["현금흐름/총자산(%)"].apply(lambda x: np.nan if x=="N/A(IFRS)" else x)
df["현금흐름/총차입부채(%)"] = df["현금흐름/총차입부채(%)"].apply(lambda x: np.nan if x=="N/A(IFRS)" else x)

# %%
df.isnull().sum()
# Out:
# Symbol              0
# Name                0
# 결산월                 6
# 회계년                 0
# 주기                  0
# 타인자본비율(%)           0
# 자기자본비율(%)           0
# 차입금의존도(%)           0
# 현금및현금성자산구성비율(%)     0
# 유형자산구성비율(%)         0
# 무형자산구성비율(%)         0
# 부채비율(%)            90
# 차입금비율(%)           90
# 총자산/총자본(%)         90
# 차입부채조달금리(평균)(%)     0
# 차입부채조달금리(기말)(%)     0
# 현금흐름/영업수익(%)        0
# 현금흐름/총부채(%)         1
# 현금흐름/총자본(%)        83
# 현금흐름/총자산(%)         1
# 현금흐름/총차입부채(%)       3
# 유보율(%)              0
# 유보액/총자산(%)          0
# 시가총액(1YRF)          0
# 시가총액(2YRF)          0
# Target              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132 entries, 0 to 1135
# Data columns (total 26 columns):
# Symbol             1132 non-null object
# Name               1132 non-null object
# 결산월                1126 non-null float64
# 회계년                1132 non-null int64
# 주기                 1132 non-null object
# 타인자본비율(%)          1132 non-null float64
# 자기자본비율(%)          1132 non-null float64
# 차입금의존도(%)          1132 non-null float64
# 현금및현금성자산구성비율(%)    1132 non-null float64
# 유형자산구성비율(%)        1132 non-null float64
# 무형자산구성비율(%)        1132 non-null float64
# 부채비율(%)            1042 non-null float64
# 차입금비율(%)           1042 non-null float64
# 총자산/총자본(%)         1042 non-null float64
# 차입부채조달금리(평균)(%)    1132 non-null float64
# 차입부채조달금리(기말)(%)    1132 non-null float64
# 현금흐름/영업수익(%)       1132 non-null float64
# 현금흐름/총부채(%)        1131 non-null float64
# 현금흐름/총자본(%)        1049 non-null float64
# 현금흐름/총자산(%)        1131 non-null float64
# ...

# %%
#df['현금흐름/총부채(%)'] = df['현금흐름/총부채(%)'].astype('float')
#df['현금흐름/총자본(%)'] = df['현금흐름/총자본(%)'].astype('float')
#df['현금흐름/총자산(%)'] = df['현금흐름/총자산(%)'].astype('float')
#df['현금흐름/총차입부채(%)'] = df['현금흐름/총차입부채(%)'].astype('float')

# %%
df_0 = df[df["Target"] == 0]
df_1 = df[df["Target"] == 1]

# %%
df_0.head()
# Out:
#       Symbol      Name   결산월   회계년      주기  타인자본비율(%)  자기자본비율(%)  차입금의존도(%)  \
# 368  A005930      삼성전자  12.0  2017  Annual      28.92      71.08       6.23
# 369  A000660    SK하이닉스  12.0  2017  Annual      25.53      74.47       9.18
# 370  A068270      셀트리온  12.0  2017  Annual      26.65      73.35      19.33
# 371  A207940  삼성바이오로직스  12.0  2017  Annual      44.64      55.36       7.60
# 372  A005490     POSCO  12.0  2017  Annual      39.94      60.06      26.77
#
#      현금및현금성자산구성비율(%)  유형자산구성비율(%)  ...  현금흐름/영업수익(%)  현금흐름/총부채(%)  \
# 368            10.12        37.01  ...         26.49        81.12
# 369             6.50        52.98  ...         52.04       158.34
# 370            12.64        25.46  ...         50.62        56.30
# 371             4.99        21.07  ...         -5.82        -0.81
# 372             3.31        40.35  ...         10.04        18.59
#
#      현금흐름/총자본(%)  현금흐름/총자산(%)  현금흐름/총차입부채(%)    유보율(%)  유보액/총자산(%)  \
# ...

# %%
df_1.head()
# Out:
#     Symbol  Name   결산월   회계년      주기  타인자본비율(%)  자기자본비율(%)  차입금의존도(%)  \
# 0  A000010  조흥은행  12.0  2003  Annual      96.76       3.24      19.72
# 1  A000090  두산상사  12.0  1997  Annual      90.84       9.16      68.03
# 2  A000110  제일은행  12.0  2004  Annual      95.61       4.39      24.51
# 3  A000130  한일은행  12.0  1998  Annual      96.85       3.15      23.28
# 4  A000160  대한중석  12.0  1998  Annual     137.30      -1.00       0.00
#
#    현금및현금성자산구성비율(%)  유형자산구성비율(%)  ...  현금흐름/영업수익(%)  현금흐름/총부채(%)  현금흐름/총자본(%)  \
# 0             1.52         2.12  ...        -13.48        -1.22       -35.07
# 1             9.03        16.37  ...         -0.91        -1.60       -12.21
# 2             1.19         2.71  ...          7.32         0.51        11.34
# 3             1.89         2.18  ...          1.09         0.13         3.50
# 4             2.54        17.40  ...       -427.84       -57.25      -365.51
#
#    현금흐름/총자산(%)  현금흐름/총차입부채(%)  유보율(%)  유보액/총자산(%)  시가총액(1YRF)  시가총액(2YRF)  \
# ...

# %%
df_0 = df_0.fillna(df_0.mean())
df_1 = df_1.fillna(df_1.mean())

# %%
df_0.describe()
# Out:
#               결산월     회계년   타인자본비율(%)   자기자본비율(%)   차입금의존도(%)  \
# count  762.000000   762.0  762.000000  762.000000  762.000000
# mean    11.880577  2017.0   47.856509   52.143491   22.098202
# std      0.941197     0.0   21.929596   21.929596   16.635935
# min      3.000000  2017.0    4.530000    0.630000    0.000000
# 25%     12.000000  2017.0   30.567500   37.032500    6.730000
# 50%     12.000000  2017.0   48.630000   51.370000   21.640000
# 75%     12.000000  2017.0   62.967500   69.432500   33.570000
# max     12.000000  2017.0   99.370000   95.470000   71.610000
#
#        현금및현금성자산구성비율(%)  유형자산구성비율(%)  무형자산구성비율(%)       부채비율(%)     차입금비율(%)  \
# count       762.000000   762.000000   762.000000    762.000000   762.000000
# mean          7.451115    32.181168     3.793740    190.995328    83.676457
# std           7.199007    20.119851     7.138598    620.490529   363.839389
# min           0.000000     0.010000     0.000000      4.750000     0.000000
# ...

# %%
df_1.describe()
# Out:
#               결산월          회계년    타인자본비율(%)   자기자본비율(%)    차입금의존도(%)  \
# count  370.000000   370.000000   370.000000  370.000000   370.000000
# mean    10.425824  2003.645946   103.964514   21.606297    57.259811
# std      3.216235     6.422061   117.652320   25.053130   102.919253
# min      1.000000  1994.000000     0.000000   -1.000000     0.000000
# 25%     12.000000  1998.000000    61.035000   -1.000000    16.305000
# 50%     12.000000  2002.000000    86.260000   12.040000    43.195000
# 75%     12.000000  2009.000000    97.915000   36.560000    67.945000
# max     12.000000  2018.000000  1247.190000   93.840000  1408.830000
#
#        현금및현금성자산구성비율(%)  유형자산구성비율(%)  무형자산구성비율(%)       부채비율(%)      차입금비율(%)  \
# count       370.000000   370.000000   370.000000    370.000000    370.000000
# mean          4.599189    26.432459     1.494243   1048.251000    551.575143
# std           7.038127    23.834749     4.513036   2735.286755   2066.521848
# ...

# %%
df_concat = pd.concat([df_0,df_1])

# %%
df_concat.head()
# Out:
#       Symbol      Name   결산월   회계년      주기  타인자본비율(%)  자기자본비율(%)  차입금의존도(%)  \
# 368  A005930      삼성전자  12.0  2017  Annual      28.92      71.08       6.23
# 369  A000660    SK하이닉스  12.0  2017  Annual      25.53      74.47       9.18
# 370  A068270      셀트리온  12.0  2017  Annual      26.65      73.35      19.33
# 371  A207940  삼성바이오로직스  12.0  2017  Annual      44.64      55.36       7.60
# 372  A005490     POSCO  12.0  2017  Annual      39.94      60.06      26.77
#
#      현금및현금성자산구성비율(%)  유형자산구성비율(%)  ...  현금흐름/영업수익(%)  현금흐름/총부채(%)  \
# 368            10.12        37.01  ...         26.49        81.12
# 369             6.50        52.98  ...         52.04       158.34
# 370            12.64        25.46  ...         50.62        56.30
# 371             4.99        21.07  ...         -5.82        -0.81
# 372             3.31        40.35  ...         10.04        18.59
#
#      현금흐름/총자본(%)  현금흐름/총자산(%)  현금흐름/총차입부채(%)    유보율(%)  유보액/총자산(%)  \
# ...

# %%
df_concat.describe()
# Out:
#                결산월          회계년    타인자본비율(%)    자기자본비율(%)    차입금의존도(%)  \
# count  1132.000000  1132.000000  1132.000000  1132.000000  1132.000000
# mean     11.405084  2012.635159    66.195698    42.162253    33.590954
# std       2.106414     7.261341    74.383840    27.087204    62.564714
# min       1.000000  1994.000000     0.000000    -1.000000     0.000000
# 25%      12.000000  2009.000000    35.502500    19.297500     9.117500
# 50%      12.000000  2017.000000    56.550000    42.960000    25.380000
# 75%      12.000000  2017.000000    80.032500    63.382500    42.552500
# max      12.000000  2018.000000  1247.190000    95.470000  1408.830000
#
#        현금및현금성자산구성비율(%)  유형자산구성비율(%)  무형자산구성비율(%)       부채비율(%)      차입금비율(%)  \
# count      1132.000000  1132.000000  1132.000000   1132.000000   1132.000000
# mean          6.518949    30.302173     3.042138    471.193737    236.611540
# std           7.267992    21.563906     6.488296   1691.714608   1237.166451
# ...

# %%
df_concat.isnull().sum()
# Out:
# Symbol             0
# Name               0
# 결산월                0
# 회계년                0
# 주기                 0
# 타인자본비율(%)          0
# 자기자본비율(%)          0
# 차입금의존도(%)          0
# 현금및현금성자산구성비율(%)    0
# 유형자산구성비율(%)        0
# 무형자산구성비율(%)        0
# 부채비율(%)            0
# 차입금비율(%)           0
# 총자산/총자본(%)         0
# 차입부채조달금리(평균)(%)    0
# 차입부채조달금리(기말)(%)    0
# 현금흐름/영업수익(%)       0
# 현금흐름/총부채(%)        0
# 현금흐름/총자본(%)        0
# 현금흐름/총자산(%)        0
# 현금흐름/총차입부채(%)      0
# 유보율(%)             0
# 유보액/총자산(%)         0
# 시가총액(1YRF)         0
# 시가총액(2YRF)         0
# Target             0
# dtype: int64

# %%
#df_concat.to_excel("EDA_final_0128.xlsx")
